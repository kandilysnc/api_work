# %%
import requests

# %%
response = requests.get('https://api.darksky.net/forecast/b82654b4f199aad130cedeeb1233d5a3/40, -78')
current_temperature = response.json()
print(current_temperature)
# Out:
# {'latitude': 40, 'longitude': -78, 'timezone': 'America/New_York', 'currently': {'time': 1559837506, 'summary': 'Overcast', 'icon': 'cloudy', 'nearestStormDistance': 61, 'nearestStormBearing': 173, 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 79.45, 'apparentTemperature': 79.82, 'dewPoint': 63.39, 'humidity': 0.58, 'pressure': 1010.25, 'windSpeed': 6.39, 'windGust': 7.24, 'windBearing': 301, 'cloudCover': 1, 'uvIndex': 3, 'visibility': 10, 'ozone': 326.56}, 'minutely': {'summary': 'Overcast for the hour.', 'icon': 'cloudy', 'data': [{'time': 1559837460, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837520, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837580, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837640, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837700, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837760, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837820, 'precipIntensi
# ...

# %%
API_KEY = 'b82654b4f199aad130cedeeb1233d5a3'

# %% [markdown]
# b82654b4f199aad130cedeeb1233d5a3 >> API KEY!

# %%
current_temperature.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
current_temperature ['currently'] ['temperature']
# Out:
# 79.45

# %%
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/48, -101')
random_current_temperature = response.json()
print(random_current_temperature)
random_current_temperature.keys()
random_current_temperature ['currently'] ['temperature']
# Out:
# {'latitude': 48, 'longitude': -101, 'timezone': 'America/Chicago', 'currently': {'time': 1559837635, 'summary': 'Clear', 'icon': 'clear-day', 'nearestStormDistance': 129, 'nearestStormBearing': 267, 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 73.07, 'apparentTemperature': 73.07, 'dewPoint': 46.52, 'humidity': 0.39, 'pressure': 1012, 'windSpeed': 10.83, 'windGust': 10.83, 'windBearing': 125, 'cloudCover': 0.04, 'uvIndex': 6, 'visibility': 10, 'ozone': 311.45}, 'minutely': {'summary': 'Clear for the hour.', 'icon': 'clear-day', 'data': [{'time': 1559837580, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837640, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837700, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837760, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837820, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837880, 'precipIntensity': 0, 'precipProbability': 0}, {'time': 1559837940, 'precipInte
# ...

# %% [markdown]
# jangan posting API KEY di github!

# %%
# !touch.env
# Out:
# /bin/sh: touch.env: command not found

# %% [markdown]
# akan buat new blank file called .env

# %%
# !pwd
# Out:
# /Users/dronejournalismlab
